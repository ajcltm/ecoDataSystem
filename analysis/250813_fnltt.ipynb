# %%
# %cd "C:/Users/ajcltm/vscode/data/250811_ecoDataSystem"
# Out:
# C:\Users\ajcltm\vscode\data\250811_ecoDataSystem
# C:\Users\ajcltm\vscode\data\250811_ecoDataSystem\.venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from etl.extract.extracter_fnltt import Extracter_fnltt

# %%
ex_fnltt = Extracter_fnltt()

# %%
ex_fnltt.extract("00260985")
# Out:
# Error: 조회된 데이타가 없습니다.

# %%
from etl.extract.extracter_stockcorpfnltt import Extracter_stockcorpfnltt

# %%
ex_s = Extracter_stockcorpfnltt()
ex_s.extract()
# Out:
# Target corporation codes: ['00434003', '00430964', '00388953', '00179984', '00420143', '00401111', '00435534', '00430186', '00430201', '00430210']...
#   corp_code fs_div                 유동자산                비유동자산  \
# 0  00126380    CFS  195,936,557,000,000  259,969,423,000,000
# 1  00164742    CFS  101,724,717,000,000  180,738,638,000,000
# 2  00113526    CFS    8,595,169,639,226   21,796,606,390,430
#
#                   자산총계                유동부채                비유동부채  \
# 0  455,905,980,000,000  75,719,452,000,000   16,508,663,000,000
# 1  282,463,355,000,000  73,362,103,000,000  107,291,812,000,000
# 2   30,391,776,029,656   9,409,864,309,283   11,166,703,478,740
#
#                   부채총계                자본금                이익잉여금  \
# 0   92,228,115,000,000    897,514,000,000  346,652,238,000,000
# 1  180,653,915,000,000  1,488,993,000,000   88,665,805,000,000
# 2   20,576,567,788,023  1,846,657,275,000    2,591,941,106,956
#
# ...

# %%
ex_s = Extracter_stockcorpfnltt()
target = ex_s.get_target_corpcode()
len(target)
# Out:
# 3888

# %%
from repository.repository_corpcodeinfo import Repository_corpcodeinfo

corpcodeinfo = Repository_corpcodeinfo().select_all()

# %%
corpcodeinfo
# Out:
#        corp_code          corp_name  \
# 0       00434003                 다코
# 1       00430964              굿앤엘에스
# 2       00388953  크레디피아제이십오차유동화전문회사
# 3       00179984             연방건설산업
# 4       00420143     브룩스피알아이오토메이션잉크
# ...          ...                ...
# 113097  01913987      지엠에프십사호선박투자회사
# 113098  01913996      지엠에프십오호선박투자회사
# 113099  01914001      지엠에프십육호선박투자회사
# 113100  01913127              디지탈테크
# 113101  01913491                피유란
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation
# 1                                      Good & LS Co.,Ltd.
# 2       Credipia 25th Asset Securitization Specialty L...
# 3                                                youn bao
# 4                             BROOKS-PRI Automation, Inc.
# ...                                                   ...        ...
# 113097                  GMF NO.14 Ship Investment Company
# ...

# %%
corpcodeinfo[corpcodeinfo["corp_code"] == "00260985"]
# Out:
#      corp_code corp_name    corp_eng_name stock_code  modify_date
# 1945  00260985      한빛네트  HanbitNet, Inc.     036720     20170630

# %%
import pandas as pd
corpcodeinfo['stock_code'].replace({" " :pd.NA}, inplace=True)
corpcodeinfo['stock_code']==" "
# Out:
# C:\Users\ajcltm\AppData\Local\Temp\ipykernel_11948\2749476138.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   corpcodeinfo['stock_code'].replace({" " :pd.NA}, inplace=True)
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 113097    False
# 113098    False
# 113099    False
# 113100    False
# 113101    False
# Name: stock_code, Length: 113102, dtype: bool

# %%
corpcodeinfo[corpcodeinfo["stock_code"].notnull()]
# Out:
#         Unnamed: 0 corp_code          corp_name  \
# 0                0  00434003                 다코
# 1                1  00430964              굿앤엘에스
# 2                2  00388953  크레디피아제이십오차유동화전문회사
# 3                3  00179984             연방건설산업
# 4                4  00420143     브룩스피알아이오토메이션잉크
# ...            ...       ...                ...
# 113097      113097  01913987      지엠에프십사호선박투자회사
# 113098      113098  01913996      지엠에프십오호선박투자회사
# 113099      113099  01914001      지엠에프십육호선박투자회사
# 113100      113100  01913127              디지탈테크
# 113101      113101  01913491                피유란
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation
# 1                                      Good & LS Co.,Ltd.
# 2       Credipia 25th Asset Securitization Specialty L...
# 3                                                youn bao
# 4                             BROOKS-PRI Automation, Inc.
# ...

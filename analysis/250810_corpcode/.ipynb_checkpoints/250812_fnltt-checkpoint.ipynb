# %%
from src.etl.extract.Extrater_fnltt import Extrater_fnltt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.etl.extract.Extrater_fnltt import Extrater_fnltt
#
# ModuleNotFoundError: No module named 'src'

# %%
ex = Extrater_fnltt()
data = ex.extract(corp_code="00126380")
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ex = Extrater_fnltt()
#       2 data = ex.extract(corp_code="00126380")
#       3 data
#
# NameError: name 'Extrater_fnltt' is not defined

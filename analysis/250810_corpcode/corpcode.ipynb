# %%
from pathlib import Path
import pandas as pd

# %%
dir = Path().cwd().joinpath("corpcodeinfo.csv")
df = pd.read_csv(dir)

# %%
df.dropna(subset=['stock_code'])
# Out:
#         Unnamed: 0  corp_code          corp_name  \
# 0                0     434003                 다코
# 1                1     430964              굿앤엘에스
# 2                2     388953  크레디피아제이십오차유동화전문회사
# 3                3     179984             연방건설산업
# 4                4     420143     브룩스피알아이오토메이션잉크
# ...            ...        ...                ...
# 113052      113052    1913987      지엠에프십사호선박투자회사
# 113053      113053    1913996      지엠에프십오호선박투자회사
# 113054      113054    1914001      지엠에프십육호선박투자회사
# 113055      113055    1913127              디지탈테크
# 113056      113056    1913491                피유란
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation
# 1                                      Good & LS Co.,Ltd.
# 2       Credipia 25th Asset Securitization Specialty L...
# 3                                                youn bao
# 4                             BROOKS-PRI Automation, Inc.
# ...

# %%
df[~df.stock_code.replace({" ": pd.NaT}).isna()]
# Out:
#         Unnamed: 0  corp_code  corp_name  \
# 1945          1945     260985       한빛네트
# 1957          1957     264529       엔플렉스
# 1958          1958     358545     동서정보기술
# 2698          2698     231567      애드모바일
# 3770          3770     359614        리더컴
# ...            ...        ...        ...
# 113021      113021    1626391  오가노이드사이언스
# 113026      113026     136776    제이준코스메틱
# 113027      113027    1227039     브릿지바이오
# 113032      113032     532855    한국유니온제약
# 113041      113041     307189    에스케이엔펄스
#
#                                     corp_eng_name stock_code  modify_date
# 1945                              HanbitNet, Inc.     036720     20170630
# 1957                                   Nplex,Inc.     040130     20170630
# 1958    Dong Seo Information Technology Co., Ltd.     055000     20170630
# 2698                                                  032600     20170630
# 3770                          LEADER COMM.Co.,Ltd     056140     20170630
# ...
